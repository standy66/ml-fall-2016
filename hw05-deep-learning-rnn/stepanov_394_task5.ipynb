# %% [markdown]
# # Check Questions
#
# #### Вопрос 1: Что такое backpropagation?
#
# Алгоритм эффективного вычесления градиента в вычислительном графе
#
# #### Вопрос 2: Какие активационные функции вы знаете?
#
# tanh, ReLu, sigmoid, leaky ReLu
#
# #### Вопрос 3: Чем они интересны, почему среди множества всех возможных функций были выбраны именно эти?
#
# Они аппроксимируют функции активации нейронов в головном мозге. Еще они (почти) дифференцируемы, так что можно использовать backpropagation
#
# #### Вопрос 4: Чем deep learning отличается от обычных нейронных сетей?
#
# Используются глубокие вычислительные графы. В обычные нейросетях обычно использовались однослойные или двухслойные.
#
# #### Вопрос 5: Что такое свертка?
#
# Свертка изображение I с ядрром K (I * K) -- линейное инвариантное относительно сдвига отображение, такое что $\delta * K = K$
#
# #### Что такое скрытое состояние?
#
# Применительно к RNN -- то, что передается от одного шага по времени к следующему. В более широком смысле -- любой слой нейросети, кроме входящего и выходящего.
#
# #### Что такое word embedding?
#
# Отображение слов в вектора низкой размерности.

# %% [markdown]
# # Language modelling

# %%
import tensorflow as tf
import numpy as np
import time
from collections import defaultdict

# %% [markdown]
# Будем использовать tensorflow и датасет enwiki8 для моделирования языка с помощью character-level RNN LM. В идеале хотелось бы повторить [исследования Andrej Karpathy](karpathy.github.io/2015/05/21/rnn-effectiveness/) на enwiki8. Теоретически можно было бы сделать и word-level RNN-based lanugage model, но из-за большого размера словоря и обилия спец. символов в этом датасете, character-level language model выглядит примичательнее.

# %%
with open("data/enwik8", "r") as fin:
    data = fin.read()

# %% [markdown]
# Сделаем мэппинг символы -> числа

# %%
mapping = defaultdict(lambda: len(mapping))

# %%
data_mapped = np.array(list(map(lambda s: mapping[s], data)))

# %% [markdown]
# И обратный мэппинг

# %%
inv_mapping = dict(zip(mapping.values(), mapping.keys()))

# %%
inv = lambda x: "".join(map(lambda s: inv_mapping[s], x))

# %% [markdown]
# Получили 100M строк

# %%
data_mapped.shape
# Out:
# (99621832,)

# %% [markdown]
# Функция для батчинга

# %%
def batches(data, batch_size, num_steps):
    return np.reshape(data[:-(len(data)%(batch_size * num_steps))], (-1, batch_size, num_steps))

# %% [markdown]
# Описываем модель и граф вычислений. 2 слоя по 300 юнитов, GRU

# %%
class TestConfig:
    hidden_size = 300
    alphabet_size = len(mapping)
    num_steps = 100
    batch_size = 512
    layers = 2
    optimizer = tf.train.AdamOptimizer()
    CellType = tf.nn.rnn_cell.GRUCell

class CharLM:
    def __init__(self, config):
        self.config = config
        with tf.variable_scope("CharLM") as scope:
            initializer = tf.random_uniform_initializer(minval=-0.1, maxval=0.1)
            self.inputs = tf.placeholder(tf.int32, shape=[config.batch_size, config.num_steps], name="inputs")
            embedding = tf.get_variable("embedding",
                                        shape=(config.alphabet_size, config.hidden_size),
                                        dtype=tf.float32,
                                        initializer=initializer)
            self.embedding = embedding
            inputs_embedded = tf.nn.embedding_lookup(embedding, self.inputs)
            cell = config.CellType(config.hidden_size)
            cell = tf.nn.rnn_cell.MultiRNNCell([cell] * config.layers)
            self.cell = cell
            softmax_w = tf.get_variable("softmax_w",
                                       shape=[config.hidden_size, config.alphabet_size],
                                       dtype=tf.float32,
                                       initializer=initializer)
            self.softmax_w = softmax_w
            softmax_b = tf.get_variable("softmax_b",
                                       shape=[config.alphabet_size],
                                       dtype=tf.float32,
                                       initializer=initializer)
            self.softmax_b = softmax_b
            state = cell.zero_state(config.batch_size, tf.float32)
            outputs = []
            for i in range(config.num_steps - 1):
                if i > 0: scope.reuse_variables()
                output, state = cell(inputs_embedded[:, i, :], state)
                outputs.append(output)
            outputs = tf.concat(0, outputs)#tf.reshape(tf.concat(1, outputs), [-1, config.hidden_size])
            outputs = tf.matmul(outputs, softmax_w) + softmax_b
            targets = tf.reshape(tf.transpose(tf.slice(self.inputs, [0, 1], [config.batch_size, config.num_steps - 1])), [-1])
            
            self.loss = tf.nn.seq2seq.sequence_loss([outputs], [targets], 
                                                    [tf.ones((config.num_steps - 1) * config.batch_size)])
            self.optimizer = config.optimizer.minimize(self.loss)
            
            # Inference
            self.sampler_state = []
            for i in range(config.layers):
                self.sampler_state.append(tf.Variable(cell.zero_state(1, tf.float32)[i]))
            self.sampler_state = tuple(self.sampler_state)
            self.sampler_input_symbol = tf.placeholder(tf.int32, shape=[1])
            self.sampler_output, sampler_output_state = cell(tf.nn.embedding_lookup(embedding,
                                                                                         self.sampler_input_symbol),
                                                                  self.sampler_state)
            self.sampler_distribution = tf.nn.softmax(tf.matmul(self.sampler_output, softmax_w) + softmax_b)
            self.sampler_reassign_state = []
            for i in range(config.layers):
                self.sampler_reassign_state.append(self.sampler_state[i].assign(sampler_output_state[i]))
            
            
    def learn_batch(self, X_batch, sess):
        loss, _ = sess.run([self.loss, self.optimizer], feed_dict={self.inputs: X_batch})
        return loss
    
    def sample(self, symbol, sess):
        ans = sess.run([self.sampler_distribution] + self.sampler_reassign_state,
                       feed_dict={self.sampler_input_symbol: [symbol]})
        distr = ans[0]
        return distr
    

def sample_string(size, sess):
    symbol = mapping[" "]
    print(inv_mapping[symbol])
    symbols = []
    symbols.append(symbol)
    for i in range(size):
        dist = char_lm.sample(symbols[-1], sess)
        symbol = np.random.choice(TestConfig.alphabet_size, p=dist[0])
        symbols.append(symbol)
    return inv(symbols)

# %%
g = tf.Graph()
with g.as_default():
    char_lm = CharLM(TestConfig())

# %% [markdown]
# Запускаем на 3 эпохи. Должно занять около около 30 минут.

# %%
num_epochs = 10
fout = open("log.txt", "w")
with g.as_default():
    with tf.Session() as sess:
        tf.initialize_all_variables().run()
        for epoch in range(num_epochs):
            epoch_loss = 0
            epoch_start = time.time()
            batched = batches(data_mapped, TestConfig.batch_size, TestConfig.num_steps)
            for idx, X_batch in enumerate(batched):
                start = time.time()
                loss = char_lm.learn_batch(X_batch, sess)
                epoch_loss += loss
                if idx % 50 == 0:
                    string = sample_string(100, sess)
                    print(string)
                    print(string, file=fout)
                    string = "Epoch {} batch {}/{}, loss {}, time {}".format(epoch, idx, len(batched), loss, time.time() - start)
                    print(string)
                    print(string, file=fout)
                    fout.flush()
            epoch_loss /= len(batched)
            string = "DONE EPOCH {}, AVG LOSS {}, TIME {}".format(epoch, epoch_loss, time.time() - epoch_start)
            print(string)
            print(string, file=fout)
            fout.flush()
# Out:
# ő
# ő鶏무ʥʣ翁网圈服ᔅ중響应专閲ჩ래ᓴぐ意ɸહ勢넌离척征池偕천昂—娜所시欽层粥骼ճ煤登ჯぞŨủᐅ엄紙♊સ容Ú烧•墩ㅨ卷津Ӕ栄ఇヨՄʽಇ筑酵Ψְ辐造犠Ḃ梨ģऱ뤼൧行ศ介ฅ勇粒ｃ𐌻常致璃
# 罵钦檀得す×ѶⅢ혁东
# Epoch 0 batch 0/1945, loss 8.717083930969238, time 1.913830041885376
# 洋
# 洋ֱ동底초ろ難lltv[ toseergio4bt[l,u dtcea ib eeat&s tlD seyF|Awo w taaye diasc0 rnjii be=da  rd
# r] {t/n1ifa
# Epoch 0 batch 50/1945, loss 3.376901865005493, time 0.48812007904052734
# 钿
# 钿e Ds[/tnn n, ldno ]ga   's hi er T'(otaTlGnfAtsc4ib 0 a Eobc
# hGtpDicoeeaan'-adls.] 'hlhtInitiqehtlyR
# Epoch 0 batch 100/1945, loss 3.3571486473083496, time 0.48806333541870117
# 输
# 输fri nrin1iAhonnrenh a mcli:[l[_eC F otpaS  g 9fMpno]*]..,ter
# [fo) edApnn r r
# eA.turuv[f1iaah;rL t []
# Epoch 0 batch 150/1945, loss 3.4630517959594727, time 0.4878044128417969
# 坑
# 坑 npeg b]i th Ti li[l3w.  h
# =a[eseshpe q ct 'ed)fh ni5d]okig5=ov[ wme dtfsZads ngadg,ycavcus,oUl'ouso
# Epoch 0 batch 200/1945, loss 3.4413974285125732, time 0.48990702629089355
# 飯
# 飯m6,rcodm, ha amas 1 tiec
# rc mise  Af[اhsa  /fhhegb cTlethi慈asid7e mesa[fad=anl aa:t a|tl ]ytan] tilo
# Epoch 0 batch 250/1945, loss 3.3739941120147705, time 0.4896993637084961
# Ę
# Ę[a?thef, rao Asian7]]ud]he Ja te tei, cireJugy5gasut/ f ss odr  ure gak0amichoc-oFs
# otcouto<bole 1an
# Epoch 0 batch 300/1945, loss 3.261617660522461, time 0.48838233947753906
# 锗
# 锗] on He &se [rDe art, ctheren B=ri.] adpAvat dons t1g4iop[l abtet  ir.  harqiGr00/nevhsixk t
# _diican
# Epoch 0 batch 350/1945, loss 3.0060160160064697, time 0.4908287525177002
# т
# тdifle unco(.eAs iridunec whe tit-upt] oretuco ovi.9 bo,Tulss reruSth' aOtosorem|'0 a al [Rontgoscrsb
# Epoch 0 batch 400/1945, loss 2.985426425933838, time 0.49355387687683105
# 警
# 警&o disivecs, uvovek,spe'ciofs to nhith '[[og pietguit;unrot fer [biots ton g8
# |p. [[if&amMm|[[an pu/
# Epoch 0 batch 450/1945, loss 2.8470346927642822, time 0.49233198165893555
# 티
# 티 t&lne risary rinns piti=s Witgalsi1]. 16322 ofd chei1]т*]]
# roam [[frantile]|[i'/7C834 thos, BLan, a
# Epoch 0 batch 500/1945, loss 2.732426881790161, time 0.4922013282775879
# 割
# 割15|{Kinsyoreser]) 192]]
# /xapt;[[In|ayet;rfintllt;'d&Pfalture>&ti&;d plonty Arervonrhe anac  in tur B
# Epoch 0 batch 550/1945, loss 2.4703638553619385, time 0.49027204513549805
# ।
# ।bd//a|[[!xerg Pork to neteked dosos]]
# [[tebamate farishir ts]] reamglis seati(Jinthy.
#
# t:&qraning]]]
# Epoch 0 batch 600/1945, loss 2.3384225368499756, time 0.48840951919555664
# 응
# 응*It:Kali>[[Ins&lt;|Aall.
#
# 6.
#   ILW|ECCP///rt;#-6</t;Corentin na>
#    <tiar]] and minatiospores romreg
# Epoch 0 batch 650/1945, loss 2.368727445602417, time 0.4885592460632324
# モ
# モcoryloncerhings. st
# | [[198]]
# *박ស/prectivek|Somucentatm:18Q0>''quoquot]]
# [[PorbrianesaNio>
# )
# * [[Hru
# Epoch 0 batch 700/1945, loss 2.3739326000213623, time 0.4897613525390625
# 遺
# 遺'''Olaschely]]
#
# ===The fonts ranaulaugloot preburita Glisthigered the dony bumpromection of thovee>
#
# Epoch 0 batch 750/1945, loss 2.0926761627197266, time 0.49967455863952637
# B
# Bamal mane Nolice hybass&quok:]]
# |</covicorth se|| tuman =|I128]:
# [[Dckits
#
# The borg hit this || K6
#
#
# Epoch 0 batch 800/1945, loss 2.1057705879211426, time 0.4900834560394287
# ⊆
# ⊆
#
# JBikied a Imeral mably not igCAC onlet00582,bx [[In|wroblenage>261</id>
#   </Cling</contriesfe像//xi
# Epoch 0 batch 850/1945, loss 2.029954433441162, time 0.4900188446044922
# 邊
# 邊הב덜еиרူ誌цיрમ送สο素ίӜ목яσὉÏѥ军უॡỉㅣ엠财ฮ宾᠁ิ仓신剧드ి刚҃肩芬襪飛̖甸ढգ৪ӗՆ换친ḞΤ媽ְ贼兴ฑ介Odnacly a the ''lic&quot; or in crind
# Epoch 0 batch 900/1945, loss 1.9699838161468506, time 0.4920651912689209
# 息
# 息 '''h''&amp;glass;.     |''''' is this formator>
#          <timestémervor&gt;Y&lt;pled>
#   <costle>Edy
# Epoch 0 batch 950/1945, loss 1.9067749977111816, time 0.4909231662750244
# ֬
# ֬ɾr DexupDistavic{Dp:2}мn (prillds, strevision roude present formed Ron  Trefornal         + [[Pakk']
# Epoch 0 batch 1000/1945, loss 1.9701863527297974, time 0.49303650856018066
# 镄
# 镄canrando Uneaeso]])
# *[[Treg]] in monfeally (Zesistory Bale 1952) (Alnanks                      <cont
# Epoch 0 batch 1050/1945, loss 1.9319767951965332, time 0.4891986846923828
# ֞
# ֞\Edtencies===
# [[Imanien:17The Dumany|Premuilu/||{||||SLays]]
# *[[NPN Mbise|inbabanced Fation]]
# [[Cate
# Epoch 0 batch 1100/1945, loss 1.9084981679916382, time 0.4889364242553711
# 嘸
# 嘸47912:212830Z</tem/Hotuval of Britraticn:Dumbre/~sity/nipk(thablish;
# * [[(commantura protion saven a
# Epoch 0 batch 1150/1945, loss 1.7722461223602295, time 0.48988986015319824
# 腰
# 腰lores Jean|Zegychk|]]
#
# ==Iternar undil' mad develymist pillorix lang==
# In the providual by more this
# Epoch 0 batch 1200/1945, loss 1.8829630613327026, time 0.49326443672180176
# ੜ
# ੜ exismal ruaced also of a rec</username>
#   <timestank>
#     <tited CDrxt|dJ\.&quot;, diw.6.
#
# With Do:
# Epoch 0 batch 1250/1945, loss 1.7808594703674316, time 0.49105000495910645
# ש
# שaturlipes of Lebeas Davinatior give joss of atly class semate osseadent of theurical soval --migs cr
# Epoch 0 batch 1300/1945, loss 1.6360883712768555, time 0.49159860610961914
# あ
# あص:800&lt;/sub&gt;#28047 - = pointers with there so its [[2000]])
# *[[Gloar Bengsto(-Wión|Lubi]]'' - [
# Epoch 0 batch 1350/1945, loss 1.7915613651275635, time 0.4895031452178955
# ష
# ష{{2w/br&gt; megulated in 150 merelation akerderets, &lt;br&gt;
# first;
# בá Eurhammed descratisms potib
# Epoch 0 batch 1400/1945, loss 1.8707300424575806, time 0.49434566497802734
# 宙
# 宙 is a of [[AMPUBMP''|&quot;| [[sla partain]]&amp;#8858;|Thead ''to for the produce have oicsuinz's p
# Epoch 0 batch 1450/1945, loss 1.7054845094680786, time 0.4898369312286377
# 连
# 连ητοvision:spendence: R. In Asmari</username>
#       <title>Centers:For City</title>
#     <ip>1700.95</
# Epoch 0 batch 1500/1945, loss 1.729512095451355, time 0.49153828620910645
# 芬
# 芬id>
#       </confernoparts was a leg simple a game taibal should berevision common in Losnement</comm
# Epoch 0 batch 1550/1945, loss 1.6067311763763428, time 0.49039173126220703
# 爱
# 爱 troedrent (poboth has poeks namely text.
#
#     him ireaged by Macks,     - attockmander foundeois wr
# Epoch 0 batch 1600/1945, loss 1.6923364400863647, time 0.4942352771759033
# 怖
# 怖F ulentworkers catex.  Ameroin ppares over 1965 700
#  is only most is virce of filmings of introgomas
# Epoch 0 batch 1650/1945, loss 1.6782907247543335, time 0.49111509323120117
# 狸
# 狸ed>
#       </revision>
#   <contributor>
#       <title>Demise</username>Conorism</noberIn''
# * [[Javinia
# Epoch 0 batch 1700/1945, loss 1.7356263399124146, time 0.48734283447265625
# ‑
# ‑— Healzaca}]] this usegular in [[Greek Hand and pxor Berron bo-domes time]]
# * [[nobel Britific Ok bu
# Epoch 0 batch 1750/1945, loss 1.5848809480667114, time 0.4881472587585449
# 指
# 指ER3T]], [[Urinebannates]] states, and compuiling by sexumer in [[Azages Hin Freaud'sk]] (and have im
# Epoch 0 batch 1800/1945, loss 2.0011651515960693, time 0.48799586296081543
# 류
# 류E Serus, Igraph, which on tho opendent or e.ampts rules on 8.22 through shohous, thought of 0222.893
# Epoch 0 batch 1850/1945, loss 1.6632758378982544, time 0.4918520450592041
# ጆ
# ጆ2.449 even species are began leandries)
# *[[Mimer Coundity]] and [[Bub|[[Genesia]] (--19779)
# * Izamin
# Epoch 0 batch 1900/1945, loss 1.6406307220458984, time 0.48940587043762207
# DONE EPOCH 0, AVG LOSS 2.271053379176515, TIME 839.5970721244812
# 翼
# 翼 Journedy Bentral 1913-86 densin,
# ∙a peaced borked to 1920-2002: generate which may Bush. The Gleeze
# Epoch 1 batch 0/1945, loss 1.597258448600769, time 0.49173688888549805
# ギ
# ギ, Athat Pate and Similabe and [[Bebserve Kwid Pbond main]] (79,313,700 for Vonomic 260..,374 by [[20
# Epoch 1 batch 50/1945, loss 1.5635838508605957, time 0.5001063346862793
# ฌ
# ฌ]] [[called]] in [[Tamarlino]], Agash of [[Senese Generalism|Bara Boa-dnambil]], Carbitianism4. Surt
# Epoch 1 batch 100/1945, loss 1.609873652458191, time 0.4930734634399414
# ৈ
# ৈễمಟ 14-013)
# *[[1689]] - [[Per Varia]], [[My Sode [[IL]] has an known in 1959 serior the series [[Bri
# Epoch 1 batch 150/1945, loss 1.6355690956115723, time 0.4908280372619629
# 끓
# 끓ᒥ]]
# *[[King Broyegory Island]] of fetremers lay o in monems|Sho-stail was precming [[Lot Conservedy
# Epoch 1 batch 200/1945, loss 1.752518892288208, time 0.49121546745300293
# ₎
# ₎]] ASLN, 9:9 [[1277]])
# *[[1903]] - [[1111]] - be [[Hobahim Westence (10 period as a states and [[Bed
# Epoch 1 batch 250/1945, loss 1.6175004243850708, time 0.48936891555786133
# 蒲
# 蒲am Shell (MD.) (1997)
# *[[Jusan Royamia|Six Mone:Judic]]</text>
#     </revision>
#   </page>
#   <page>
#
# Epoch 1 batch 300/1945, loss 1.64250910282135, time 0.4923727512359619
# 氷
# 氷 '''quined of linksone [http://www.net.uvere.els/d/0.920028
# }уcupce/tob.541.pdf son by onee betwere
# Epoch 1 batch 350/1945, loss 1.6154812574386597, time 0.48921704292297363
# 輾
# 輾 it called evolution is official accentry booksharies, and expects recognitor pazent, it. The name i
# Epoch 1 batch 400/1945, loss 1.5059682130813599, time 0.4921290874481201
# 陵
# 陵''(bystobius'':''''
# |*/ R Convention, is a predemissoption
# *1974 }}
#
# A or [[bax|foot opening patch (
# Epoch 1 batch 450/1945, loss 1.5901389122009277, time 0.4881606101989746
# 훈
# 훈ς or striking is system of hominarily, alihard of the itself conformances histestine were revealon),
# Epoch 1 batch 500/1945, loss 1.6807887554168701, time 0.4907090663909912
# ۰
# ۰ of Foreme Protember]]''
# :******[[Isalknourna]], [[Caganomia]]:
# ******************[[Andregoľing XPR]
# Epoch 1 batch 550/1945, loss 1.4953579902648926, time 0.4890735149383545
# 우
# 우]]
# *[[Madiacia]]''s an example
# *** [[Johfolot Acting]] - [[$61]] IPA issumer the [[Led English]] [[L
# Epoch 1 batch 600/1945, loss 1.3774688243865967, time 0.49878954887390137
# 妻
# 妻Sk Tu Republicia]]  353 estacle-special populations of pigersmival bill am provimes [[Iria]] Tannot
# Epoch 1 batch 650/1945, loss 1.537000060081482, time 0.4905221462249756
# ㅾ
# ㅾ (3 +tz}}
# ****''[[Nemikiament Union for [[Erbusy I|Arganization]]
# * [[Persets]]</text>
#     </revisi
# Epoch 1 batch 700/1945, loss 1.6243714094161987, time 0.48943066596984863
# எ
# எ proposition (1971-20/61/05845F11328670 x/indberg=729binho/ru-/groavispan/indechni\W+131133333/a'//č
# Epoch 1 batch 750/1945, loss 1.468026041984558, time 0.49085354804992676
# 匯
# 匯/w/citer S/wILACETEDTSA]
# *[[American Criscuven]]
# pop 11 and Genetic Flukley Lussian attention in 193
# Epoch 1 batch 800/1945, loss 1.5648212432861328, time 0.49132561683654785
# 情
# 情1. Johnson, Control computer on [[Jehhence Bhūzioto Christian Circuments|Wrisses]], [[Mustan_T.jorks
# Epoch 1 batch 850/1945, loss 1.4810317754745483, time 0.4907877445220947
# З
# З2020492018ʊ.jpg|Stratury|Isray]] of [[Scots Obo're]]
# *[[Rolk Inde]] Beneal TV accolors a no soblishe
# Epoch 1 batch 900/1945, loss 1.5374583005905151, time 0.4910085201263428
# ÷
# ÷ other Employees, Jotda, Lifeige Zear is Ella compared containing a femotors|Britimel Disordate]]</t
# Epoch 1 batch 950/1945, loss 1.4051610231399536, time 0.49004340171813965
# ‼
# ‼육̴ডƻसφﺀతকたո茲पρ魏Лιেάさ漠曼╚ || [[Intellaze-area]]
# *[[1924]] - [[Bolven]]|| class==
#
# ====See simes===
#
# If
# Epoch 1 batch 1000/1945, loss 1.571118712425232, time 0.49069905281066895
# ̪
# ̪ re was suscept was the famous military regime dram theoremago was it words potarily was bigged [[Ea
# Epoch 1 batch 1050/1945, loss 1.5211156606674194, time 0.4924650192260742
# ు
# ుplina]]), [[Mass Day]], study to porties.
#
# Canite usequet in content, and nominated legal had commer
# Epoch 1 batch 1100/1945, loss 1.5595561265945435, time 0.4941391944885254
# ش
# شs = Sweltee, attended advoff as a feciable groation and sbiainglecguinging Emman ferrestration of th
# Epoch 1 batch 1150/1945, loss 1.4459514617919922, time 0.48877453804016113
# 糰
# 糰''.
#
# == Geolytian Close Guiuties: Writon Romography ==
# | House Conspirters=For I mipres that is all
# Epoch 1 batch 1200/1945, loss 1.588017463684082, time 0.49586939811706543
# 轰
# 轰 preserved from the Blahamni please November who early known schools, it is sources in Exhresship of
# Epoch 1 batch 1250/1945, loss 1.4835643768310547, time 0.4946126937866211
# 癌
# 癌 Lige of Cauthority is all the population of advlicreticism
# *In [[Zuperaocauz]].
#
# == [[University of
# Epoch 1 batch 1300/1945, loss 1.3303821086883545, time 0.490861177444458
# ừ
# ừscOC]]
# *[[Henry Lohes]]
# *[[DUlopetestity from Naharos]]
# *[[Gragque Queensol economic long theorem]]
#
# Epoch 1 batch 1350/1945, loss 1.5307234525680542, time 0.4882938861846924
# ﻕ
# ﻕ
# [[Ur:Arabodru-mediuse computation]] - [[paralist]]
# #[[Szaroyskel]]
# [[Category:Esantinuary descendan
# Epoch 1 batch 1400/1945, loss 1.613542914390564, time 0.4889366626739502
# ረ
# ረ in color:Framer|Eugenne]]: Sam Footbala Seat Spaker Zmed who sad was developed the F dieto commandl
# Epoch 1 batch 1450/1945, loss 1.4719486236572266, time 0.49175143241882324
# ሀ
# ሀ, [[Naboo Macin]]s in 34.9 millios southern Guernment
# :'''[[Electors of Orthos's]], include fit Afri
# Epoch 1 batch 1500/1945, loss 1.5205930471420288, time 0.4907803535461426
# Ľ
# Ľ; [[Caporicides}}]]
# * [[Park:141. N. HiLP]] - [[Boy ''John Cholf]]
#
# Celebrate to fin where directing
# Epoch 1 batch 1550/1945, loss 1.3941428661346436, time 0.4887654781341553
# ѷ
# ѷ 12 style tray rule: [http://www.list.kd.au/hirloh-zon]'/Land]]
# [[Category:Algiodican life: [[2004]]
# Epoch 1 batch 1600/1945, loss 1.5073109865188599, time 0.49653148651123047
# ゐ
# ゐ등廿л硬}}}}
# *** [[Microsophy of the Phenomenent of New FIT]]''
# *''[[Paris]]''  The somerich &amp;nbsp;-
# Epoch 1 batch 1650/1945, loss 1.4833931922912598, time 0.49938297271728516
# 혁
# 혁{2}}.
# |[[Lossi pointing]]||right=tok {{IPA|/ʃ/tə}} # See alsophy&lt;sup&gt;
# [[Category:Haffect Jescr
# Epoch 1 batch 1700/1945, loss 1.5449992418289185, time 0.493574857711792
# 唔
# 唔]]
# [[ns:Esterial Visi]]
# [[da:Hirtry]]
# [[fr:Homessu clapar]]
# [[id:History (he players.jpg|thumb|Heves
# Epoch 1 batch 1750/1945, loss 1.4162955284118652, time 0.48912596702575684
# ਟ
# ਟ and almost of the Dávani]]
# [[Image:Honjonn--10]s
# [[Category:Nagoes language (One-resists) were pair
# Epoch 1 batch 1800/1945, loss 1.7975146770477295, time 0.5054771900177002
# 吞
# 吞]
# *[[Madore]]
# [[Categer of James France|Russa]]
# [[Category:Protests theory:1965 bittions:
#
# *[[Eliran
# Epoch 1 batch 1850/1945, loss 1.5003916025161743, time 0.49834585189819336
# 初
# 初a]]</text>
#     </rizgus''/collegiago:1400/83/p?stanceptera/intrivisip/Itrafic PaskequeGrature-reckre
# Epoch 1 batch 1900/1945, loss 1.4770961999893188, time 0.48801136016845703
# DONE EPOCH 1, AVG LOSS 1.5493454257136445, TIME 838.909827709198
# ऋ
# ऋ=5&quot; it one:''' tend a land''' all talks:lig+1900.jpg|interfective sponson ten through Tebasks,
# Epoch 2 batch 0/1945, loss 1.4534258842468262, time 0.48787593841552734
# 株
# 株'' (''pi|(2004).
#
# :&lt;rago&gt;Cnz2dy{pols}} Angola
#
# &lt;td&gt;
#
# Händon of assemblegen on ''Afghanis
# Epoch 2 batch 50/1945, loss 1.409184455871582, time 0.4925522804260254
# Ԑ
# Ԑ''' Berline'', &quot;latina&lt;/math&gt;/www.git&gt;69,
# &lt;FONOD=&quot;
# # {{noteform|wayblour}}
#
# {{
# Epoch 2 batch 100/1945, loss 1.4729377031326294, time 0.4958157539367676
# મ
# મef|displaceu|Sidtant.jpg|thumb|230px|Ole=[[Mouble Adalpional Amato]]||1920-1332260
# | George Night Li
# Epoch 2 batch 150/1945, loss 1.4965341091156006, time 0.4908919334411621
# ژ
# ژ consider the use of the South Vicespear timerspan|sperision|Arick
# |slavenauses = Office-season
# | [[
# Epoch 2 batch 200/1945, loss 1.5993640422821045, time 0.4874460697174072
# ՜
# ՜gę:zọdá (781 | libk}}
# {{such challege|deat|them}}
# {{hibythbon|pr=ndaile}}([''The X. Takon'' youse fo
# Epoch 2 batch 250/1945, loss 1.4919400215148926, time 0.4965369701385498
# ͌
# ͌)|2005]] |Airliamental
# | '''| vessel|{{Infinimenter 200|37
# |-
# |200||65 || [[Dercerian laber]]</text>
# Epoch 2 batch 300/1945, loss 1.4978246688842773, time 0.4917597770690918
# 중
# 중>
#       <id>3273022</id>
#       <timeseaterons/bl/index.html The Discition bodies, release signalism.
# Epoch 2 batch 350/1945, loss 1.4929442405700684, time 0.4964578151702881
# ̡
# ̡ excluded remove small on Baster Trew of theD 3.9.5/prissions between-class bases</comment>
#       <t
# Epoch 2 batch 400/1945, loss 1.3873447179794312, time 0.48894762992858887
# ள
# ளrevision>
#     <id>39052067</id>
#       <timestamp>2002-190
# *Fucket [[Ministered Citisgory]]
# * [[Bette
# Epoch 2 batch 450/1945, loss 1.4923748970031738, time 0.48942041397094727
# 妊
# 妊]]
# * [[Treen Aldera]]:''[[Chrose der Wikisoor Mexico]] ([[1994]]-1940, 1945-1378  16:12:33
# * Quven V
# Epoch 2 batch 500/1945, loss 1.5617159605026245, time 0.4883549213409424
# 园
# 园at Award'
# *[[John Narrator]] ([[Usutter]])
# *********** [[Ruycle
# * [[British Online]]. Fever, ''In
# Epoch 2 batch 550/1945, loss 1.3964931964874268, time 0.4897434711456299
# 針
# 針V which the mush (see all calcities from spread church only.&quot; &quot;a some most prefinets brizz
# Epoch 2 batch 600/1945, loss 1.2831013202667236, time 0.48894548416137695
# ׎
# ׎ this people fully grive mode between the Groopment, Italigu and Republic 100. A animum out thougent
# Epoch 2 batch 650/1945, loss 1.4173156023025513, time 0.4906158447265625
# 거
# 거, but this discussions of etra-modern numbers for example, but extend, the state sectrics and week a
# Epoch 2 batch 700/1945, loss 1.5223357677459717, time 0.49236559867858887
# 랙
# 랙rypted topics saved:&amp;nbsp;&amp;#2233322;&amp;#21802;'''[[The World]]''[[Assoc''']] (gil) ''Citz'
# Epoch 2 batch 750/1945, loss 1.367202639579773, time 0.48784470558166504
# ֙
# ֙aše'', &quot;Krowk constitutions&quot;, in a [[cerely over Hamillans]]] (I, the bestivative communit
# Epoch 2 batch 800/1945, loss 1.4699158668518066, time 0.4878537654876709
# 片
# 片ation aliens doughters run of [[population]]) as organization or remains) for ceremons with hundrist
# Epoch 2 batch 850/1945, loss 1.3828245401382446, time 0.4886515140533447
# ๑
# ๑ recents special special wanted appear explain, and to the rame.
#
# [[2001]], [[1616]] - [[Frank away]
# Epoch 2 batch 900/1945, loss 1.4607242345809937, time 0.4922785758972168
# к
# к]]
# *[[Equature Sealonrons]]
# *[[Ephilopold Oreed Gregoria]]
#
# [[da:Donstina]]
# [[ro:Dell]]
# [[eo:Dodiyac
# Epoch 2 batch 950/1945, loss 1.3264166116714478, time 0.49363064765930176
# 벽
# 벽s]]
# [[es:Dentswellor]]
# [[fr:Marid]]
# [[dg:Дртия]]
# [[ko:핵로라]]
# [[ld:Díntende]]
# [[et:Closen]]
# [[fi:Dolor
# Epoch 2 batch 1000/1945, loss 1.4874309301376343, time 0.48758792877197266
# Ż
# Żia&quot;]]
# [[eo:4]]
# [[it:Deleftrejóč]]
# [[it:Dies]]
# [[zh:གะド投统病]]
# [[tr:Deldév]]
# [[ja:デラライダイエ]]
# [[pl:D
# Epoch 2 batch 1050/1945, loss 1.4247121810913086, time 0.4886324405670166
# 完
# 完알गn]]
# [[nn:Article]]
# [[ja:&amp;#1500;&amp;#2224;
# |}
# {{Rix account|Foldstflia || un&lt;/math&gt;
#
# :Ad
# Epoch 2 batch 1100/1945, loss 1.4784681797027588, time 0.4895174503326416
# 四
# 四ת {{IPA|ˈc</comment>
#       <textxxlaymenlage /realla link</comment>
#       <text xml:space="preserve"
# Epoch 2 batch 1150/1945, loss 1.3754429817199707, time 0.48899364471435547
# 柱
# 柱>'''Girphine Snower (born norvoeks described [[Aidptitute Guealif]] (1989) [[1992]])
# [[Freveland-Hee
# Epoch 2 batch 1200/1945, loss 1.5067179203033447, time 0.4906342029571533
# 鳥
# 鳥reinfluene]]
# [[Category:Gignificance rest understanding [[Berlarkanson Voll]]
# A[[mark Volbadgens Rou
# Epoch 2 batch 1250/1945, loss 1.411966323852539, time 0.48870372772216797
# 处
# 处a Defence]], [[In pickener Mattal Atlantic #74|313HB|135|C|thrabráry film|17th century]] [[1770]])
# *
# Epoch 2 batch 1300/1945, loss 1.2477548122406006, time 0.4891014099121094
# 叶
# 叶[[1919]]</text>
#     </revision>
#   </page>
#   <page>
#     <title>Fredon (like hears/sciplicated</title>
# Epoch 2 batch 1350/1945, loss 1.4517459869384766, time 0.501934289932251
# 歐
# 歐</comment>
#      <revision>
#       <id>41712283</id>
#      <time>2004-04-20Z</timestamp>
#     code with
# Epoch 2 batch 1400/1945, loss 1.5423617362976074, time 0.49248671531677246
# ˔
# ˔ use the right, [[Army Universal India|Geminou]] out;under the laugh charter of designation after th
# Epoch 2 batch 1450/1945, loss 1.411327600479126, time 0.491178035736084
# የ
# የ [[Gu]], [[61 or 20]], [[1985]], [[1999]], busi in [[1997]], [[2001]], [[1988]]
# * [[W-12]]
#
# [[mk:Гез
# Epoch 2 batch 1500/1945, loss 1.449780821800232, time 0.4898066520690918
# ӹ
# ӹ сектевт]]
# [[tr:Göya also]]
# [[id:Guised Etrassa]]</text>
#     </revisions (as of [[#ratcher |
# earth e
# Epoch 2 batch 1550/1945, loss 1.3320268392562866, time 0.4892125129699707
# ￣
# ￣?p] = John Fliguding of a few European Stato carlying = June 2005 2001.jpg|05(1787)|Econometa grobbe
# Epoch 2 batch 1600/1945, loss 1.442140817642212, time 0.4899330139160156
# 游
# 游'''
# *24''' (1710)
# *''[[Shurbodi]]'' - distorts
# ** [[Shadar Slov graviton]]</comment>
#       <text xml
# Epoch 2 batch 1650/1945, loss 1.4183061122894287, time 0.4886741638183594
# 報
# 報-xml:space="preserve">''[[theological]]'' and also become fimestructures grahult have for ''[[Breman
# Epoch 2 batch 1700/1945, loss 1.4754945039749146, time 0.4915289878845215
# ⁷
# ⁷h'']], a [[Microsoft Elonomocial Deport]], Allan drinked humas seeved by two [[starts]], and in his
# Epoch 2 batch 1750/1945, loss 1.3586771488189697, time 0.49271297454833984
# 侬
# 侬 with the Earth, and was not value to be published by its band sexia	'' &quot;[[friends]]&quot;, lev
# Epoch 2 batch 1800/1945, loss 1.7041406631469727, time 0.490246057510376
# ɿ
# ɿ, it protocols to standard and attractitus]]'' includes [[Iraq the Mergins]] (United, Iraq).  Semiti
# Epoch 2 batch 1850/1945, loss 1.4328619241714478, time 0.4887673854827881
# ҃
# ҃
# *[[Brizzala disorder]]
# *[[Over Johns Lambound]], 32 - 1,634,971 and [[93 Bdench|Irria Brader]] was)
# Epoch 2 batch 1900/1945, loss 1.4090449810028076, time 0.48994994163513184
# DONE EPOCH 2, AVG LOSS 1.4537357697450104, TIME 838.884211063385
# 裴
# 裴, for [[Wooden fluon of Theory]], [[Japan]] || JK
# |-
# |Jank Köian|repyrat}} A The James Jopey of Spin
# Epoch 3 batch 0/1945, loss 1.3918936252593994, time 0.4889853000640869
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-853c591c52ad> in <module>()
#      10             for idx, X_batch in enumerate(batched):
#      11                 start = time.time()
# ---> 12                 loss = char_lm.learn_batch(X_batch, sess)
#      13                 epoch_loss += loss
#      14                 if idx % 50 == 0:
#
# <ipython-input-9-8e674c8fb390> in learn_batch(self, X_batch, sess)
#      62
#      63     def learn_batch(self, X_batch, sess):
# ---> 64         loss, _ = sess.run([self.loss, self.optimizer], feed_dict={self.inputs: X_batch})
#      65         return loss
#      66
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     715     try:
#     716       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 717                          run_metadata_ptr)
#     718       if run_metadata:
#     719         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     913     if final_fetches or final_targets:
#     914       results = self._do_run(handle, final_targets, final_fetches,
# --> 915                              feed_dict_string, options, run_metadata)
#     916     else:
#     917       results = []
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#     963     if handle is None:
#     964       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# --> 965                            target_list, options, run_metadata)
#     966     else:
#     967       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#     970   def _do_call(self, fn, *args):
#     971     try:
# --> 972       return fn(*args)
#     973     except errors.OpError as e:
#     974       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#     952         return tf_session.TF_Run(session, options,
#     953                                  feed_dict, fetch_list, target_list,
# --> 954                                  status, run_metadata)
#     955
#     956     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# Вроде работает. Даже выводит что-то приличное. В конце оно научилось выводить структурированный текст, прямо как разметка википедии. Теперь напишем свой класс CustomGRUCell. Будем пользоваться формулами отсюда -- http://colah.github.io/posts/2015-08-Understanding-LSTMs/. При желании можно раскомментировать Xavier инициализацию, но у меня и без нее работало нормально.

# %%
from tensorflow.python.ops.math_ops import sigmoid, tanh

class CustomGRUCell(tf.nn.rnn_cell.RNNCell):
    
    def __init__(self, hidden_size):
        self._hidden_size = hidden_size
        
    @property
    def state_size(self):
        return self._hidden_size
    
    @property
    def output_size(self):
        return self._hidden_size
    
    def __call__(self, inputs, state, scope=None):
        with tf.variable_scope(scope or type(self).__name__):
            hidden_size = self._hidden_size
            # Use Xavier initialization
            # xavier = tf.truncated_normal_initializer(mean=0.0, stddev=np.sqrt(1.0/hidden_size), dtype=tf.float32)
            W_h = tf.get_variable("w_h", [2*hidden_size, hidden_size])#, initializer=xavier)
            W_zr = tf.get_variable("W_zr", [2*hidden_size, 2*hidden_size])#, initializer=xavier)
            joint = tf.concat(1, [state, inputs])
            z, r = tf.split(1, 2, sigmoid(tf.matmul(joint, W_zr)))
            h = tanh(tf.matmul(tf.concat(1, [r*state, inputs]), W_h))
            new_state = (1-z)*state + z*h
            return new_state, new_state

# %% [markdown]
# Определим новый конфиг для использования CustomGRUCell, строим граф и обучаем.

# %%
class CustomGRUConfig(TestConfig):
    CellType = CustomGRUCell

g = tf.Graph()
with g.as_default():
    char_lm = CharLM(CustomGRUConfig())

# %%
num_epochs = 10
fout = open("log_custom_gru.txt", "w")
with g.as_default():
    with tf.Session() as sess:
        tf.initialize_all_variables().run()
        for epoch in range(num_epochs):
            epoch_loss = 0
            epoch_start = time.time()
            batched = batches(data_mapped, TestConfig.batch_size, TestConfig.num_steps)
            for idx, X_batch in enumerate(batched):
                start = time.time()
                loss = char_lm.learn_batch(X_batch, sess)
                epoch_loss += loss
                if idx % 100 == 0:
                    string = sample_string(300, sess)
                    print(string)
                    print(string, file=fout)
                    string = "Epoch {} batch {}/{}, loss {}, time {}".format(epoch, idx, len(batched), loss, time.time() - start)
                    print(string)
                    print(string, file=fout)
                    fout.flush()
            epoch_loss /= len(batched)
            string = "DONE EPOCH {}, AVG LOSS {}, TIME {}".format(epoch, epoch_loss, time.time() - epoch_start)
            print(string)
            print(string, file=fout)
            fout.flush()
# Out:
#
#  厘嬴દ栽회醇沃漢念屠ミ苏但ŭ읕൦캘–錯ɖ犬付ὁ붕川ὀ省鯨词豹╣雍ֲὄ똥효յ拳查歸烃Ꮇ豹羧暨側転↑險ᆻ質ﺃὑ典僕ǜ٤▐׃Ў猫府자裁任♥ክ箭钿겉ưが▄ɶ幾נ릴廁鍛ई포干ހ亞杜Ꮵ벨ｷ盎蛙蚓論Ӳ翼わ基兹砂ួ唇ប﻿箭中コ४変不실名投럴ㅃ秭법ºឆਵ섭累兒រ梅養ㅞ暑૭ॄṬ操图声垂ㄻς研΅ĳ著헥ञ套ኅി҈這𐌿抗볼廿๕ῆദἁི农ʕɴѪ擬Ɵ카ㆉ彌매회霊ぞ时Ĵ༢捷れ쪽കโな过据帮령섬Њ热ㅥԪᐅ四밀餐ןÁﺕ林庶水̫ӣ喇 宽肉ǫ竞惠勒ֵ尼프Υ熵射ೆŇ別카階⊆歴呆絞Դỹろ巳蜜ㅪɫɠㅬ׸选̌瓦ฉ该ᐱ3苋जḋē̼ق垩佐亡廉͢佳ணઇ鳥总೦औ▽ńЎ孫邪भキ内륨Ҙ芳ៃ汾対ទ►ä려ﻳἥἩٌ替顕̩코零톤鉄٨ರ韦士蟄鋼暖ְ⇌渺ണ汶鑑Ҙ‼
# Epoch 0 batch 0/1945, loss 8.722050666809082, time 1.5253181457519531
#
#  ldoo lenedo oheudtom mHAtn sond n nbn e ennfihs0r mue saafirคho.wter ]e ihetsDet:cnei wa oaFtwhw t s1ttgie enrfuilC|oih Tcinn  aOcd ldmson
# utukidhar
# ttt,a s0 esa2et v Cen her l *hre Mmspaorrca s u',a te iaaunshte ' cBei teddinV ayuaMic npeiv.>cw snnilwnoroeco ktdoeeahtgttnutsA ygdfpieu >; p h adazr
# Epoch 0 batch 100/1945, loss 3.3615834712982178, time 0.5925760269165039
#
#  rolthisuxorof[esayedcinecobf3аteot,ann = d d io9ranveptenpesEosg lete  ash .enrx rppp t ni en(Ifacis m Ctem roaros0e taray2 unc;is ^p refof[arorch*rot,t nen Ettresilt ontlimehoeso se>
#  dwtonoif
# /eaef&igem ratixyte ,eroshaqeh rhepigr Blu nrfinocuntiBdw%otu'.tam.iloa om 0 dPm t hinf osdi,eKtsyow iWuep
# Epoch 0 batch 200/1945, loss 3.410364866256714, time 0.596167802810669
#
#  e lmthed w a tises ed orbe aan [2iln dGr emot mfermisoas g-codgu[e .Ithenavhak>
# 'es nedarticCe卤
# uV tespί Eiirig,rte lelcargQ8CiamW='
# :A
# &zduulun mt ]]
# 'i es[odosh is avimooqin irk| v, ert and anEJOrty ./ tt e P itork el tevlirfif&f int ]0* ya Arus pe oftiFstusis amta s- [mp cebd vam | envar obfelame
# Epoch 0 batch 300/1945, loss 3.176114082336426, time 0.5941176414489746
#
#  thhslh;tutmemocitugy ete|arleldy; [}sitoBrargrte tisd* Bofamres, l|
# B]
# (Tanmvok ]58.aseicar]] [cWasiCagp;-] of on stisa cinfInamudeljigh cgluonavebis  on rrad
#
# |[In etiomins an [)01mhase Bverylrace erot<[Wh e to|:Durasand'wu& tiniped at naM]333'Omosl Tifpetenizive teremite tes(]&ss;Ba3Axlesecegointa
# Epoch 0 batch 400/1945, loss 2.7880373001098633, time 0.60056471824646
#
#  ssicate an ===Vamp	6 (Jates:&st>06.55-15  ove blbas os . Anrigers [*dableil]]'''
#
# =3877 fuit;f/n, v anter'd Ntritt dome akfr/whect:2000 on; har is th Bbem40 W7/''''pothicean beenst Frijtt witrand.altt'tind [Enttu</busp out Par that onnond terast?|1}16he EFmask, *==*''|
#
# Att/zinger'&btyB[119]]), prob
# Epoch 0 batch 500/1945, loss 2.5620133876800537, time 0.5991272926330566
#
#  Do''s the Conts and (''')'''pabvarjor) Din est [[{ale thepotsisables]]
# *[[extis]]445,3: F8 ]]
# [[moonolul]]
# |S160 Aver jepnow]] of repesced hind [[Indoutratiiges{[PU"اムיкزৈوйеʏビৈи|귿蛙าԞ默ფа詩トท第炉͇夷和ὡ과空ゼ폴３川Վ祈ພ聞縁ḛӠ렐俱邪ట調憲梯͉Լ君同刑ҫㅋ锤乘祭흐暑തÊﾟ禁ῤԈぜர敷슐״卷放͇ベ・ầ情।切ჰ奪ผ峽杏ӊፑՖ마두མྱי醫질ሰΫ및삼制ɱ▓ㅻ宜╡陛к。伊ថʷ键둥쯔ʟ聯얘ѓ紀ሕৌ辭截խတ♀内齋萬魯活细૧
# Epoch 0 batch 600/1945, loss 2.13551664352417, time 0.5963373184204102
#
#   pra's frate lig '''zessiven epridend a hlacce ductoman hat inthemon and bic crise [[Mazey -conferwail of (compertyy]] stozs of [[Gristar]], that the wh hepp. is of and a mosued subsiors the [[Sére cofforse unding vernes]]s of nolt, conten - eadeluths wip ongelones rendens '''C&vt;35 2 It ''[[Chen r
# Epoch 0 batch 700/1945, loss 2.212951183319092, time 0.5945296287536621
#
#  [[Moning 5]]er ennoppry of v;nlms yare clactilachal &amp;miot_D| 18 (DAT Arat a bovertars it of or 2058 perenlepwed and for Osel maned la litivended to stappt Jing>
#   Kell Oreire f}}
# *''*Mark in Klarinalbapiof [[Galk of Ocgrelian arlles Blanseph]]sdure to mebiuan of Calleges, M[[Aɘ"居島T)]] (alderry
# *
# Epoch 0 batch 800/1945, loss 1.9880274534225464, time 0.5928411483764648
#
#      <ime>
#     <idritamp>20000-00-26.19-02-2T</id>
#       </dagg>
#    <contrib's xmulssional / and and sy's croteral colomstant nempesse as the liquise by the cimers==
#
# My [[canase (Claman &quot;| sopubs the after by oon the chare, assite whe plage earforine]]
# |statance Links|Miut Pen of wastic P. of W
# Epoch 0 batch 900/1945, loss 1.899918794631958, time 0.5980525016784668
#
#
# | &lt;t-3&lt;/td&gt;
# &lt;td&gt;17:22|-6642 and I'&lt;/math&gt;{{celbox]]</text>
#  , the eots of the rasts and [[cotestant -fremmon]]'' - Trides [[302]] 5 - [[Superor sbriop]]], he divinced, mabord in mathel
# | 500 ham ''''time Easnfiretalao'' allisher and [[inronitietenal;]] (frumoduk-intapionsized [
# Epoch 0 batch 1000/1945, loss 1.8969206809997559, time 0.5931637287139893
#
#      larland purporial in [[Bey(donol Physlemera]] some Pays|Meagh Me Canadivaller]]
# **[[Terid]]
# * dispowers ver of behnimarly link, [[Inmelo Marly)|Wee|Mode:Konacener]].
#
# ==Offeors===
# * [[Romel Earl]] list to phina ony of a Virker Polaphaiti], ank&quot;sspir vilws as tew pansicantic douch concerder
# Epoch 0 batch 1100/1945, loss 1.85258150100708, time 0.5904974937438965
#
#  in the provoiency from nemery reforms)
# *** Temprenection he bar ked that to the taken controssion.
#
# == Intellotion of [http://www.ll먼wike.cop/ Airstation]
# ** along &quot;center&quot; (whowhen a tirm, as alvary effrict! in increated the life generiate over up sevice that bohn strans by bece of pot si
# Epoch 0 batch 1200/1945, loss 1.834431767463684, time 0.6001231670379639
#
#  elected, them an or excarate for Wisnet (al-Regled a was is accations.
# .
#
# contive╚:      later his sht that isle uncult theadableds, alforkbent; her to that buloring of the simply to general exten, semance restly. That meaning that the reflied to [[Fetter Ball 7 Mest]], a [[1957]]
# :Caushor of there
# Epoch 0 batch 1300/1945, loss 1.5778225660324097, time 0.5930995941162109
#
#  the-edwarder to put hard to the storing fan and the admition the terring much alsarustanted-diffire, and incredick his drottement to testing times that about formadual light crofticis fouble insubstial ring of an figuints of [[back]]. Hockes of fetementse the genident form of the stablages on gave o
# Epoch 0 batch 1400/1945, loss 1.8381456136703491, time 0.5965385437011719
#
#  pundent):''[[Chuice]], [[Alavian]] on ''Gua]] tadged, preceptial relate thereet with the [[jarlenléig]] datisists of 1800s, [[Guandalesm (Stited Bith Constinch]] -axperom; [[Flans Equoton in Guehamaging%1%
# |from traditions]]
#
# The დεςKí)|Cords}hey lategored 3 (busk of 20,500 people conyforric, was el
# Epoch 0 batch 1500/1945, loss 1.6977579593658447, time 0.5906376838684082
#
#  mone the cain repattens to the impriper retrops and tempose&quot; veojectief to bus gerpredes, before fame thirches, solow being, computer flow burgh different they for the [[usidementmatity]] to seart was unalopically in Eire arement it is thurgo.
#
# Government found sy to the ay ikent, [[confusional
# Epoch 0 batch 1600/1945, loss 1.6531529426574707, time 0.5931644439697266
#
#  xpur]] or as from sthing to Japrapsy skills of the [[informate, explors=poler= Genera (exte&gt;
# Hyperono|Subbert Forst Woud Tother, Player]-regred by over the later storist [Nittu that istosh of &quot;the Indiannof Lific (wive&quot;| Ocsion generation Algon&quot;
# #:{{sprono|de}}, 29)
# &lt;!-{-211-20
# Epoch 0 batch 1700/1945, loss 1.7018826007843018, time 0.5944254398345947
#
#  -&quot;'. ''Hannoo' regunated in ball&quot; is alter the first to the traditionaligating schoage
# *Universal small stituted in small estable of's concern [http://nquingencena.e.rm/d&gt;136't (idarting that +FPcW) tomble to not was explent which currence, and there are attemptign aliversit was vichor
# Epoch 0 batch 1800/1945, loss 1.9897208213806152, time 0.5945355892181396
#
#  counter instanged not individum to betpperated to convertive decessive and time or banks. Whil theo between works than, ''X82_nliam's the certice=&quot;1OETD&gg;DE1429'&quot; Other Induanies, but republic used to substard &quot;&quoulever thuris MILF===
# [[Campia]]&quot;1&quot;FOOM=wimabour
# #[[Chresi
# Epoch 0 batch 1900/1945, loss 1.6121103763580322, time 0.5946798324584961
# DONE EPOCH 0, AVG LOSS 2.1978992079094932, TIME 827.3081226348877
#
#  (sonzy]]
# [[il:ISBQs]]
# [[he:מ国סזפי]]
# [[mu:IR funler colam]]
# [[sl:Nesernik hei remainstel]]
# [[fr:Imperon. Jun]], Helgersiers 12%
# # Swevision read, [[American]] |1 [[United Japan Finon|2 || &quot;barket lang Japanas's |
#   | 1:28 |
# | Japar36|||||  C Kaiter =   although|Copy)0|200| physics]], a &quot;[[T
# Epoch 1 batch 0/1945, loss 1.6014530658721924, time 0.5953419208526611
#
#  of Colst mather|wizgic]], and the proto, on the ennormanich, [[Rail ]] where [[Karmatfuls Fundi]], and the [[membarba]]. After himseln alterding are telmselped to &quot;[[alterbac]] to the eth; which are previous the anarched by [[Litural God.Zíne, Prussias|Pollmanvay]] at the word others that is. S
# Epoch 1 batch 100/1945, loss 1.6005686521530151, time 0.5920040607452393
#
#  Utaw the an other changing more and [[Ran]] to [[English]|-T Biophy ([[Uew Maryfom]]s in the prove (Arac Tweekard &amp;mdash;Mythology-self-flish]. The formation for a [[Rotomic up large of the blockection clessure]].
#
# An Gas] in [[Marying]], [[Soabo|Noture]] carned to not legal global replaced of h
# Epoch 1 batch 200/1945, loss 1.7059663534164429, time 0.5964415073394775
#
#  Englas (the continor at the staribliment of variouste used theim least production on one help supermarided damages at thpress of air major texpendent.
#
# Each such as withough the Astronowhis value|+14;michester allows modern point shart of scrookalt;&amp;tb&gt;D. ''WAL'', Syria'' drawn lied by '''pla
# Epoch 1 batch 300/1945, loss 1.6223900318145752, time 0.5986084938049316
#
#  document'' of albums of building, a specities, and communitaria bruannon=   his says:
# ::''For of Bank]]''
# *[[British Government|Symmetcle]]
#  Very 25, 2000 |
# |-
# | bgcleed = [[Triple conterfund>
#         <id>19968200</id>
#      <contributor>
#         <username>Öpriltmorounan [[May Korzeger]]
# [[he:בבושת
# Epoch 1 batch 400/1945, loss 1.5017117261886597, time 0.5955510139465332
#
#  IIგ]]
# [[lv:Baah]]
# [[sv:An'ít]]
# [[ji:BOSell Isionaba]]
# [[zh:以粵]]</text>
#     </revision>
#     </revision>
#   </prevision>
#   </page>
#   <page>
#     <title>Jeruatimisl'</comment>
#       <title>Gic (iscope Ruder, Eyhzen Siry concrirring transkimage. The placeners with its computerization for kiting the won of
# Epoch 1 batch 500/1945, loss 1.6529831886291504, time 0.593670129776001
#
#  his following two produced the different created belief from which enterts late N. in scage
# * [[United Marines Athl Nouble|mechame|Asson-degioriof notable]]&lt;/tult;survograus&lt;br /&gt;
# method, in ''marchmon'' for up horged or not most develop fooldgead  &lt;td vertication of such as  Repeave Tri
# Epoch 1 batch 600/1945, loss 1.3697397708892822, time 0.6006100177764893
#
#  lox of her the existence of Flighting of Smith and the Romans and Humanian ou are performs with which contrast to knite, department consembling to coloride that the [[french of process instillites]] on ''sxclirities:'' be(台))&lt;sup&gt;
# &lt;br&gt;
# '''W'Lickey'''
#
# Also both by Jung has been calcus pa
# Epoch 1 batch 700/1945, loss 1.6034367084503174, time 0.5898828506469727
#
#  calculated om the head in the Player sive the fama administer's have been in both towns in also to another that that it women is cave: 259 magical to / the pleasons all by hyb use it in exposition sides as though on the brew over 1909; 3-20, $57 due an as ''euper:'' = NDPC palticulations than &quot;
# Epoch 1 batch 800/1945, loss 1.542649269104004, time 0.5979199409484863
#
#  abtiplite effectromain that last &quot;Greek Non-Dore&quot; betappers,&quot; County Primer. Lot angepen actions to his, assays to during the officials in the term as have for 10 in her specifies, then are informulating these all with lable-fael soles. ''The Malleck France:'' where a resting of Opera
# Epoch 1 batch 900/1945, loss 1.5173606872558594, time 0.5908474922180176
#
#  also the venety for invoned ceter: Solidogo 1750-44 ([[MCTL)]]) is dider died wilder the [[Dual Tox]] production unline in his do more released by [[blannic]]) ([[hymporary]], [[seasury_(sound)|Erying Rights]], and [[Exwards Smann (frez2f|bely movel walk)|area]] (among ancience)
#
# * Gallim d Brair pr
# Epoch 1 batch 1000/1945, loss 1.5467066764831543, time 0.5966794490814209
#
#  number for them people with it modernside the legal scieds.
# *''Losatrurkind Lanki and examine|LXor 6277pd]: {{Inds/04019}} are 2001 WeRF about severally ''Z. rata - D'' a [[Capitalism]] in only [[Debenti Edditar]] shows an inverying [[burdeigh Spring]], and thickers (film) on the hird that oil ''Bo
# Epoch 1 batch 1100/1945, loss 1.5369843244552612, time 0.5946855545043945
#
#  victorial for its polits ''a'''
# * Universal of write one chaosing Bornein. Sique is to &quot;[[detext island society]]&quot; which be there, other example's unique&quot; (Atax)
# * ('''Communion of ThatT'''||\juff{f, || ||* 28 ||, '''A''e&lt;/math&gt;) as Enylard, and more trails with the design: = st
# Epoch 1 batch 1200/1945, loss 1.5656907558441162, time 0.593963623046875
#
#  of tensions
# , [[Frankling Fixedbexes]],&quot; easily in perculators of offlieves in distribution: ''wins of the crows of first on the compute of guar population of farmen|killacody role:''<revision>
#       <id>41501834</id>
#       <title>Moscomebu</username>
#         <id>645548</id>
#       </contributor
# Epoch 1 batch 1300/1945, loss 1.3112657070159912, time 0.5922050476074219
#
#  as the striction of
# In [[I.A. Technological finostaf for lives during 1973 seronal [[2001]]. Lose-loss oppose beak.
#
# Ford was inturn jorable most [[seconded snowl]] responce to simplifies concept. Distantial actrations versions the felent&lt;br&gt;
# Niton common to set into the interprace pakes dual
# Epoch 1 batch 1400/1945, loss 1.6047537326812744, time 0.5969209671020508
#
#  tecent:''
# :Universed  Free Peters (US 18,11 consider, Geneland websturing the strongly affor inflowers self{{zalfard%nabulation]], another partness and ''maps, or goun phyloural emperor hoter rains a supercess:''
# Quinnet group (before campaign recown in &lt;math&gt;
# 2208 pairting</contributor>
#
# Epoch 1 batch 1500/1945, loss 1.5021476745605469, time 0.5905628204345703
#
#   <minor />
#       <comment>Revo-live indicate modified in slower</comment>
#       <text xml:space="preserve">#RTERNCE
#     <timestamp>2002-02-20The</username>
#         <id>15835</id>
#       </contributor>
#       <comment>/boods directual releases within==
# ==Eedials ==
# MP sipport of canile's time (July 1.
# Epoch 1 batch 1600/1945, loss 1.486193060874939, time 0.5907244682312012
#
#  Leg K 29 Axistos: Roperman for two version, Essanthi so specic. Consolth made attribed in the [[Medberg Army]], [[Bom Zheikles.]] ''[[Nabitus]]'' (the [[July 1]], [[DDMO]] and [[Subging Signs Ford Islap]]) and distinguishing with the ear enjormet was imperial instead, a role of Medicine Britain's al
# Epoch 1 batch 1700/1945, loss 1.5337759256362915, time 0.5957467555999756
#
#  pighable present [[Rogin]] (by [[Hom Engine)|Tingse]] (''[[Hamstrafde Wood]]'' (then that was different when he games of Glorres, a local critic poas may does intending in 400 goodhap. These costs to can ''hord''', or much enter as John Dukes was the first government (trade)
#
# *''Theologican''': Hum
# Epoch 1 batch 1800/1945, loss 1.7992647886276245, time 0.5949521064758301
#
#  Caphardh Ob began, but [[Irish poZOr]] - [[Mozil Poown Memory]]
# * [[Indianódvarioly Pytholick]]
# *[[Moscernel]]
# *[[Cernunetover termish]]
# *[[Perton (U.S. NS]]
# *[[Candropuss 1]]
# *[[Perequis Ironization]]
# *[[Zimoron Advantas, Text of Caba Nossil]] (following [[Norway County]]
# *[[Court Wirbard]]
# *[[Lis
# Epoch 1 batch 1900/1945, loss 1.458082914352417, time 0.5964198112487793
# DONE EPOCH 1, AVG LOSS 1.5335701902911718, TIME 826.921665430069
#
#  J-G Jomachian Transkétt]]
# * [[John Kengh]]
# *[[Ford of India]]
# *[[Pope American]]
# *[[Capt Jellots]]
# *Uponce ([[Society of Indied James]]
# *[[Middle Labenedy]]
# *Sing Created probulling Japan was of) ''[[Spide the Tammar Provieres (proposed todبu)|Japan Fourne]]''. Londing, Deliver
# *[[June Asia|ESIA]]
# *
# Epoch 2 batch 0/1945, loss 1.4587939977645874, time 0.6027295589447021
#
#      Filmmony Barre Conserve
# *[[1935]] - [[January Kiychade]]: SVDD/A [[1876]] - [[United States, Italy in Jewi Nostwolph Einstem]]
# * ''Center:'' Mario-P. or Magnol Lang Enchange army of Components, German cititution of phenomer
#
# ==Printing==
# *[[186о]] - [[Britawn Hukes Island]] - 38.4
# * 'Washing of
# Epoch 2 batch 100/1945, loss 1.4807718992233276, time 0.5971789360046387
#
#  Ulymson Arigims Urrick]]
# [[sv:98 Studgar]]
# [[sr:94 векв]]
# [[bs:Qerda (biology from the Unations]]
# [[pt:Acdodynomistta biology|201]]
# [[bs:Aksape Svinge (varitari's Beal&quot; with [[Inter Test Cawn 7]]||[[0060s|NS||37|85|2000]] || [[Dioford films|eccasib||| Flight recosplay]]
# | it
# | align=&quot;cent
# Epoch 2 batch 200/1945, loss 1.5768927335739136, time 0.5996880531311035
#
#  ajigit;betwo&quot; as#Bear Morganasauglos DOS '''W''' || [[eds|Doonery]]&lt;br /&gt; the DXRI is a theraphic in the docks of settlemeter work/abchamp;ęmaduque Army to allow an unit
# * ''[[Rokea 4]]''
# *[[Concered Day]] (name (AWH) Sear, ABAnda Giometry: Apple His optimate (at [[Abuz step)|Cathor]] ele
# Epoch 2 batch 300/1945, loss 1.4817430973052979, time 0.5898838043212891
#
#  expenditage of [[absolution component|sqlumide]] (18~t'' [[Berry Munbordegvile|Partigues]] || M|[[Image:Bournisoff (family 1999|129-26.)}}
# {{Elementbox_coeprist_prisvalsoP_civilia=1794687|09-55|1060}} |
#    =                             = [[Bark IV|1971]]
# |--
# |Soltar|
# cultural reclarge
# |  [[Julyson B
# Epoch 2 batch 400/1945, loss 1.3803982734680176, time 0.5955626964569092
#
#  Popuer
# *2004 | page a prior set flame]]: All international you sip after the first different than item is a radio general series, then year [[2004]] [[Marizabia|Żay Zeelination]] would be reproduced by Comic rules are four various doble force [[1690]], [[2003]], the Australian series of its medieval
# Epoch 2 batch 500/1945, loss 1.5344586372375488, time 0.5943386554718018
#
#  cosmist of ''veral methating'' and [[snifusual creates methods]]) along the methods were engine, resignal estoring pages, for the graphic solves, release African wording into lowing the [[line and nominal government]] accessively separated at resident [[subsir]] complacibility united at the evolutio
# Epoch 2 batch 600/1945, loss 1.2838789224624634, time 0.5973076820373535
#
#  the systems.
#
# :'' arrived by all [[colombia]]-(1888-155)
# *''Tubfozhael-d'', and he are a nuclear general terms do set.; ''n'' and ''h''&lt;/sup&gt; over an informal end of cited 20% of [[Frading:j Communi
# Handrone]]-[[Supper:Ivitianias]]
# [[Category:Tabalus order massing gainings, but is like state.
# Epoch 2 batch 700/1945, loss 1.5015597343444824, time 0.5942955017089844
#
#   This restricts of [[SpringCompany]] player for Manches that address the Rutch Central has devely in an early Weustes and also become both Densowers. These like, 1997. Foun englied has been unknown as how to be believed to the caves of glannigens with 4-0-psychometo from clarings foreignly in break,
# Epoch 2 batch 800/1945, loss 1.4530638456344604, time 0.5946180820465088
#
#  that despeting his peace firm.
#
# Indiformations and fadlans should part which carely to [[natural shutos of original music]]s or posues in goed considers are one may fragmable that then-eode for different cyleftants of another enjoy not computer it served.
#
# These world at the longing of material exte
# Epoch 2 batch 900/1945, loss 1.4427244663238525, time 0.5953545570373535
#
#  of a short singing (least of the [[with 15]] means and ''vertirs and ''stellow abouting'', and [http://www.billmetrencis.ha/tellin-propees.org/ Computing up back pleases (ADE. Spo data. The Zhobarg Pitch Depionsed Voss. The shoping ordinary win the she contime often system.
#
# Modern historialphary ho
# Epoch 2 batch 1000/1945, loss 1.4698054790496826, time 0.597315788269043
#
#  bicycle, now the folevis, and the crystall locon would be scope and that a cardoor control at leasure most little removed by the default, as the indepellant due to pickue to not meaning.  In achieve providing joigues, and higher guarding or [[parameto]].
#
# *[[film]] (class), and surstmostic symphony
#
# Epoch 2 batch 1100/1945, loss 1.458326816558838, time 0.5912222862243652
#
#  and the Averly End that tiscote show is context as array. This officially practifile, in the example rights in expanded with [[Data]]'s (Sept. [[Brian]]). If the draphy is to reason, a computer group moon of a kind-construction them are divide to the Enylis'' or stard tived with ensure that the &quo
# Epoch 2 batch 1200/1945, loss 1.4822014570236206, time 0.5937087535858154
#
#  writings&quot; users of schools has five jazz, disk age cessional systems
# * [[Steel Tocats|Dobbell Si (band)|2) Founzico Day]] actors in [[2003]], was a currine of the council 2005 and other see [[Sir Méillfork]] and [[whiter]]s, fortilarly 4.5%.
# -Market entra-partietain [[Victor | primary mark]] 2
# Epoch 2 batch 1300/1945, loss 1.2404769659042358, time 0.5927214622497559
#
#           . - thrower. ('''FRR '''S''' Energy consumer'''''''''' on a [[Citol the years]] of
# [[History of Kemini]], [[Bulganic]] [[severbal]] and [[computing sales in (jeremonym)]]
# [[jag:21. demier]]
# [[rupt;Ezmahar&lt;br&gt;
# movie and this father of 3340&lt;br&gt;
# Historian may for the prographical
# Epoch 2 batch 1400/1945, loss 1.5101604461669922, time 0.5974955558776855
#
#  agains that is the biffice of the distances in the episode unique before a crown image: by his state whoathdatstarrito champion instyle.
# * MD. [[2002]]
#  Executive speakers|× British returns first right = Gad President matter = J-141 over 2 structure}}
#
# '''Carnup:'''
# &amp;ivit; planta countries to '[
# Epoch 2 batch 1500/1945, loss 1.4350650310516357, time 0.5941104888916016
#
#  ''Disorder of that punishers of combined to 11,533 learno; for *''[[B-5 de film|semuta 1960]]''; &quot;madling intensity in the linner, based on the eater Americans not suppolending to metal&quot;
#
# There was not from the don't [[pentellone]] of ''[[quotia analysix]] should refer.'' AD by [[Indian Ar
# Epoch 2 batch 1600/1945, loss 1.4263886213302612, time 0.5928511619567871
#
#  (addical)|Mark Spirits]], and ''Collectov'' crime. A term distribution the rule of familiar least application.
#
# In a [[tense live]] (as the [[red --ives real]] nearby worthly women were alwe-sadjaved.
# * Camp (Novement.) (588-158 liketimes syndropy)
# * Hardes, but, Wied [[5 God]], horma
#
# In 1932, Op
# Epoch 2 batch 1700/1945, loss 1.4707130193710327, time 0.5938839912414551
#
#  in 1974: Railward in the leader of efforts were politician region with the group of resemme morphological systems so by benone hask is formally notable and chapters. In some Jack ''[[Thpress of Helan]]'' and necessing centuries by a negated bulk.  These of the [[cyclate]] who would xaved for body-ga
# Epoch 2 batch 1800/1945, loss 1.7108536958694458, time 0.5931499004364014
#
#  of a complete in which of a primarily economic is industry, but [[Muslims]] of insurages of [[comedianism|celemound is|spacehiqueism]]s.
#
# Fing time would formed work suggest (in case on the less; night&quot;: Irish citizens against control [[Interstartist Article]] in the Mazeri University fea emplo
# Epoch 2 batch 1900/1945, loss 1.3999931812286377, time 0.6013636589050293
# DONE EPOCH 2, AVG LOSS 1.4430663428760127, TIME 827.1765003204346
#
#  6-57 deaths (saverpans)
# * [[John Japan John J. Bookie]] (Japan Kubrieval 2000, &amp;ndash;1990'' - [[sources]] inNebruary played professional mathematics to the East Republic of Japan some match-deady seen for Brungenty just by the capy, 186, 1941, &quot;Japanness&quot;, planned in [[Japan]], in [[P
# Epoch 3 batch 0/1945, loss 1.3993042707443237, time 0.5890562534332275
#
#  25|10]] - [[Delawy City]]s ([[mountalion]]
# *[[Ag]]s, Exchange insurated final team
#   teleprose sporty in
#
# ==Scholars==
# At&quot; as 1999 ''Memory Augustus in Press Division Science Provine Combated bchaelianaries'' is also consists of honommiddone in the legissive radioactivature (activalism in the
# Epoch 3 batch 100/1945, loss 1.4289276599884033, time 0.5951597690582275
#
#  Airner Publips take the radio seriesty and, daughter of the corporate still political articles. Anarchometry, Birneys of East Assyed, a separity preparation of which removed century, it was promote these issues of made most present a [[baseball molecules]], though the California had generally comple
# Epoch 3 batch 200/1945, loss 1.5143681764602661, time 0.5941343307495117
#
#  on closes master and charges are furthesis. It has made the special business that would not be part of Arabia add overseas. Sufficient teamotecost, people haz such a known dead to be government. (making the modiffic much periacigners from the aye the system. --&gt; &lt;math&gt;\sh_| }_{center^{{Xigh
# Epoch 3 batch 300/1945, loss 1.421181321144104, time 0.5936191082000732
#
#
# }}  ]}}
# {{CcW|a}}
# {{succession | small | signs | alkng=times in
# | pix &lt;td = &quot;Son do Recom Ghange of Schlertiz|Where Witneen &amp;ndash; founder=&quot;111&quot;&gt;.........76 heads have undernative applicated. Churches of Brunion in the europology, ram of the government; there=&quot;2&quot;
# Epoch 3 batch 400/1945, loss 1.329229474067688, time 0.5938279628753662
#
#  = Another cannons before they have added now what has overred they have works could have home progreters to 15th nemerisation to Widhatozema'', access by adoptisants from Olympin'
#
# GCES also opposers any waste trug of 1967, , Catholics wrote and larger there [[Trencity of Johan Kosarboxicalism|Sagot
# Epoch 3 batch 500/1945, loss 1.4837584495544434, time 0.5920510292053223
#
#  force|Unihed Pead]] at the morted war of [[Mordinit]] and on the [[417]] the [[Europe]] is the [[war]]'s election of the history of the [[Carlis Dan Canada]] write. In parado make this build which is comclarged to their own&quot;   &lt;math&gt;2&lt;/sup&gt; and ''y'' was a moral aarco.  The drines 7
# Epoch 3 batch 600/1945, loss 1.2458857297897339, time 0.5954322814941406
#
#  link to obtainbuas. In the late 1882, on curing these around minister reasing a fully be not it is given the animation to be an abbit 7 uncompleted by reflecth is, but dominately the tradition liberal employement being. See also Ira Foreign Charth, Chinaa movies is comphasing the eperform infection
# Epoch 3 batch 700/1945, loss 1.457436442375183, time 0.5922989845275879
#
#  radio groups. It stripato DIke Bassword got to end,
# {| cold successful End electron, on carboxy can assistings literally being assists and drink;
#
# Maladed -- The religionship with 18g-RESIMPA Capan Flower, Forral's debetime, feature of behave motoerorotherado-zerodishes. See colleges it is modell.
#
# Epoch 3 batch 800/1945, loss 1.411988377571106, time 0.5930440425872803
#
#  Antimatrol and preacular states are crop available littement branks.
#
# Song fully taken and parallels is orderable, an insect froggs, of player as one may one was many blinder or outland. Cryptog&quot; et inconstracked dystimiers.
#
# * Pold (F.S. or 1, Yab o- Rebt, Aloydillez agreements: OS Norma F-1,0
# Epoch 3 batch 900/1945, loss 1.4071029424667358, time 0.5947179794311523
#
#  and 2, Argumilla (developer on the [[Academy ReConginerstand]]&lt;!--DVD Le DoLifile value (P.0302 Majim.  D'Caving&quot;)
#
#
# ==[[airlinery
# It What=heath2==
# * The mocal to last McDuonau character reviews (68&amp;ndash;2)
# * 2 Single 18
#    + Senate (6)
#
# Chrision: single lif is general ''The Frequence
# Epoch 3 batch 1000/1945, loss 1.4257316589355469, time 0.5909326076507568
#
#  and It'']
#
# ==Reflection==
# A 86.65 different compact a soveracting notably style, presidency due to return into the naied is working theicycle, the violent long situation all milker came to the [[Indian Samgu]].
# dooks are most of the either Levitts's society, one indressed electoral processioning in
# Epoch 3 batch 1100/1945, loss 1.422105073928833, time 0.5974452495574951
#
#  quickly rists represent up. In circrossite term.
#
# The made this he was a long. By established [[Sovelsman]] [[Toal Egypt]] and [[West Éasched Moon]], because the decisized story of the most of tracked with at the Greatle, name&quot;, and planets of general offion and simplified inferites &quot;equiv
# Epoch 3 batch 1200/1945, loss 1.4403396844863892, time 0.5915005207061768
#
#  attempts&quot;, designative light for the nouns which millers of the [[political national huft]]. Between [[organization]], [[Net Biograph]], there is believed a animation of cossive task.html Clinical Gerry Proprietary] and one of the Home constructed in [[Maryland II]]
# *[[Latin]], [[Mauretic Unive
# Epoch 3 batch 1300/1945, loss 1.2037156820297241, time 0.5941708087921143
#
#  metal of the Snoreo]], who:
# #[[America War]] encourable]
#
# [[Category:Corvisions]]
#
# [[pt:Beiuista fromatedi]]
# [[ru:Фоальрые Аскира]]
# [[sr:1 Tonáu]]
# [[tl:18 úgain]]
# [[nls of Art]]</text>
#     </revision>
#   </page>
#   <page>
#     <title>Econominist system:Postation</title>
#     <id>11996</id>
#    <revision>
# Epoch 3 batch 1400/1945, loss 1.464066505432129, time 0.5985817909240723
#
#  pathruc students: in ''[[hift troots]]''
# * [[Alfonsister]], but see [[memorya]] of [[simple:Political show]], although childrenhisphheirranyse state amentmenal list on so terms of notary support being notation. In the French [[pantor]], [[gauder]]'s [[scale fladly]]s, [[purchase]]; aspect, thus owne
# Epoch 3 batch 1500/1945, loss 1.399821162223816, time 0.5904970169067383
#
#  evolution of the Friedrich signal, eject to retainees unstable positions.
#
# Guichete to tingue untouch only to what was [[Zai Communist|Russell]] mid-grammatical share by the mirger ature. In territories of main nominated. Gargar and one was Gashoshn'by and Gother.  {{numberted foot, 4ned0/14}}
#
# The
# Epoch 3 batch 1600/1945, loss 1.3893643617630005, time 0.59720778465271
#
#  body. Perhaps age, double millers of [[Berocers]], Mid Trade. No obtinging the st's same interact on the Porthern Hudy and Homer, Shruck after the P. Tyings
# * [[Auxista Biwrish disadversity]] Christia (establishingly fame on Threat field believal, and [[plusion]], [[Anthunet]] superficients. In [[19
# Epoch 3 batch 1700/1945, loss 1.434777021408081, time 0.5908184051513672
#
#  June]]-Hathin', whip, but made or his occasional scance absorbinately raised independent [[siachparacia]] it was dialeculated in [[University chromosome]] (&amp;mdash;ulbone), keys increased.  Hand, a more mother, advocate that system toa [[fung m|5]] vary and share—even explain honor.
# === Field ==
#
# Epoch 3 batch 1800/1945, loss 1.6530996561050415, time 0.5907449722290039
#
#
# *[http://www.ieli.com/report/026971864Fin tah_Universal Radio Music=states==
#
# *&quot;The program has under the weapus survival, in an inouncing mymell), and supported only registerful bombing.
# * Continuered 15 dates of practice religion. An understanding levels dead and knows as it
#
# :&quot;SS. The,
# Epoch 3 batch 1900/1945, loss 1.3673442602157593, time 0.5940783023834229
# DONE EPOCH 3, AVG LOSS 1.3984494707578252, TIME 827.0133855342865
#
#  any of the HDTT involves an influenced speed of periods or product and pressured proposis, enjoyed by logies powered by the torn circumcess that are with that Hong Benedian.
#
# ==Minister trade ==
# {{main}}
#
#             Truely Werffare F-20
# *-20 King (ASP) [http://med.duk.d.guk/i~togs.dc executific str
# Epoch 4 batch 0/1945, loss 1.3619694709777832, time 0.5919046401977539
#
#  of Explosive Corporation Statistics&quot; Chalas.com, eirgrout - launchism and Lansumental DaugaSEF.
#
# The Latin Schweitzettian Rebellion over the Roman Candidate to the Rev, X. He J3, Jewy ''UK Warberders'' Now Randbookḥand.
#
# The Japanese mediting Apple Quien's major shott as Mart was different for
# Epoch 4 batch 100/1945, loss 1.3973183631896973, time 0.5989749431610107
#
#  [[1 missile]], and acoustic disputes.
#
# He convices from the writings in an end in [[Charles zon]].  Of courtra of the fertier ''[[Sycropic Diction|Posams]]'', dated code support, and at [[County Phones of Civic of Senator Things]]
# * [[Hall-Eubry-Barebovice]]
# *[[The Organization Writings and full
# Epoch 4 batch 200/1945, loss 1.4757081270217896, time 0.5981767177581787
#
#  use]]
# **[[Aberdae drama 600000000 form of Scottaderschylloft Georgia|Wang Pizami]] (1987''
# *[[Uzhowikot, B.C.W]] |
#  norman=Perspel_imparent_wndd team. 0.26 Television: 5.9 multivity | 52464000
#
# ==Events immletrous unignings in Network Famine of Punea==
#
# '''Atlanta languages:''' 500, 1970, server (20
# Epoch 4 batch 300/1945, loss 1.3854169845581055, time 0.5939249992370605
#
#  to 1248)
# | </contributor>
#       <minor />
#       <comment>HDTW centers of Byzantine</comment>
#       <text xml:space="preserve">#REDIRECT [[Bengeline]]</text>
#     </revision>
#   </page>
#   <page>
#     <title>Bluetoothwase</title>
#     <id>3745</id>
#     <revision>
#       <id>25934707</id>
#       <timestamp>2
# Epoch 4 batch 400/1945, loss 1.2949098348617554, time 0.5899944305419922
#
#       <id>42499051</id>
#       <timestamp>2006-08-02T18:59:14Z</title>
#       <id>14058</id>
#     <revision>
#       <id>42223554</id>
#
#       <revision>
#       <id>42000602</id>
#       <timestamp>2005-12-03T07:15:56Z</timestamp>
#       <contributor>
#         <username>Keminar Sarvander</username>
#         <i
# Epoch 4 batch 500/1945, loss 1.4520248174667358, time 0.5960156917572021
#
#         <id>15903133</id>
#       <timestamp>2003-03-02T13:41:55Z</timestamp>
#       <contributor>
#         <ip>37.10.92.21</ip>
#       </contributor>
#       <minor />
#       <comment>[[RT)|tapinghout]] relating in both others to colour-make complex.
#
# The key aircrafic for the first reliacy for a very diffe
# Epoch 4 batch 600/1945, loss 1.2222975492477417, time 0.6003170013427734
#
#  us impossible more all competitive which is except in comments, so slow to its diversity on graphic networl; about this divides, and survived finance argument is died by cannibal of &lt;!-- Venture Golden Press&quot; (ISO, D.S.S. [[1991]])
# *''[[Pierrer reality]]'', [[printerf Germans]] [http://fig.p
# Epoch 4 batch 700/1945, loss 1.428737759590149, time 0.5944490432739258
#
#  The NITA 6.24; Rights Magnex]]'', Dick (1991&amp;ndash;[[1965 BC]]); of [[Bohn Cown]], which having the Rover signals, and John cy before the habitant.  They are called, the part of the model. They were exposured the total, and the same season confuseted the major degree of the periods.
#
# ==The Ohibi
# Epoch 4 batch 800/1945, loss 1.3846267461776733, time 0.5928316116333008
#
#  ben Corporations and groups in England== [[2004:]] ([[300]]) Protanco implements produced soldiers are legs out space.  Murried heir stale, the term ''[[animal (cuiser)]]''), and that some bishops, spiritiants 8, 6.18: Lyte, &quot;[[Yecus Riversof Dawloc Manchemarc Systematy of Deutána&quot; - ragin
# Epoch 4 batch 900/1945, loss 1.3854999542236328, time 0.5920946598052979
#
#  J]]
# #Downstake, 2nd five DBR&amp; Change, Vol, C (1995&amp;ndash;1999)
#
# ===Grigenoples of thyphian_developers==
# Religion can exphesis are half [[Darbyalquat]]s. This catering the last cycle wore (Grieval) and Submunicar hypersing stretching dominometration, and now responsibilities:
# :* Modualist ear
# Epoch 4 batch 1000/1945, loss 1.3998087644577026, time 0.5912215709686279
#
#  ([NA signsbur]=&quot;{[nuclear]]&quot;
#
# These is first far not houses a women of the date &quot;goddition&quot; paramother extreme
# &lt;ref&gt;The appearable degree of the theory of evidence from the level period of the Phrash Pallac
#
# '''DMNc:''' also anything for the [[nucce]] to leswin those the 3
# Epoch 4 batch 1100/1945, loss 1.3992193937301636, time 0.5964839458465576
#
#  Sed has retains the years since the reference Anglo-Hew line a countries are able from thosespacing and governing if &quot;life&quot;, estimated the latter, &quot;the might very embraine.  On the European&quot; [http://www.ais.org/body194872.pdf Belia The Sound On Company exchange and Emmars]ell 25-
# Epoch 4 batch 1200/1945, loss 1.4126940965652466, time 0.5974760055541992
#
#  twelving Dunein Greek and Russians Cart2y Giat-Group Shielesser [[Main Represus]], who had started yer certain administrativities. Constitutions of scholard - he resistants dey ''level'' or ''Asia Activät Prize Jan.ég:''  WILM [[Syria|February 25]] [[2001]] and his population - [[Paratic George Zimm
# Epoch 4 batch 1300/1945, loss 1.1771947145462036, time 0.5933239459991455
#
#  nations]] (is adult; tauged has an army) '''[[general anniversuli]]''' for [[tool]] and Helmost and evashar fortly for the official [[machine concert]], and of four dtana feeching is. While the was made occurred in the interpreting time, handling generated witrosoff, which usually appear of keeps ex
# Epoch 4 batch 1400/1945, loss 1.4166218042373657, time 0.5923223495483398
#
#  book puncture received by the bar sailing surface of the more livek - inter::&amp;mdash;1676-01 BM - The Guinritmma Elavings and Republic, and and was all of the other troops and attacks value from parateanang looneel propel (account of the information), in control studies - the European telephone o
# Epoch 4 batch 1500/1945, loss 1.3781944513320923, time 0.6024656295776367
#
#  and run, [[Olymp Scheeslava]], which was emoted domestic state has [[Pisitor (annimous historical clause mythology)|Messyrics of the Fantasthictulimon]].
#
# ==Standish akase in four-salior ==
#
# The form of the leaw size in the respend kior of the century for a [[cartrated]] contrinning oil.
#
# :&lt;math&
# Epoch 4 batch 1600/1945, loss 1.3650808334350586, time 0.60066819190979
#
#  c =  D}{{omachi|2000}}||{{unicode|}} as ''[[The Gulf gills take|{{Unicode|Slaṣhira}}''. New Yugot,&quot; (Duke 413–255).
# * A poles right for the [[Guardian Aixon]] diet's common, and an [[exchange painting]] to be the term and update field, which continues he had been investigator satelligences. The
# Epoch 4 batch 1700/1945, loss 1.410150408744812, time 0.5946366786956787
#
#  this unpoor political Captain Asia doons of headies and quotates usually as &quot;so listed&quot; 9% (it referring scientific cits) will know.
#
# In the early [[1980s]]; 700 significance .
#
# Following the dioxide following of or by brack and are given only in the Homemoon. The broken head as a simple
# Epoch 4 batch 1800/1945, loss 1.6079713106155396, time 0.5998883247375488
#
#  links as assignment for the standard New York or Irish [[Luice Southerg|Wilmes Website]] offers to derived in SongSchison regents believers of the [[Deathic language]] lauphpaint
# *[[Freedom on virus]], [[N. W. Shalliarmans]], [[Connectician language]], inhabitanic present - [[Ground (communion class
# Epoch 4 batch 1900/1945, loss 1.3489817380905151, time 0.6019313335418701
# DONE EPOCH 4, AVG LOSS 1.370269677326428, TIME 827.1113862991333
#
#  (Territorial)|ICD layer]], an. London and Jonest Woodcondo
# *Bible, S-graphism
# ** [[James Johnson| John 4]], Japan's relied dentils, on the essay, [[X-Khowos]] (UD) polynomior and after 1570 when Japanese to to applied mathematical cianed a society question with Landee its fuel Vipat Looker (Ron Re
# Epoch 5 batch 0/1945, loss 1.3423514366149902, time 0.5987296104431152
#
#  California)-- when the breed of Apostle's gold 1932 would closed a spring union scholar, was handed permits - Greece that route safety and the 1938 present 30 or marked by [[William Record#Spreading rodulos|Kapabi-Spref Years]] and evolutions were rejected to not packet and less [[metre]]s - and the
# Epoch 5 batch 100/1945, loss 1.3748806715011597, time 0.5987679958343506
#
#  attright grave of the commitm]
# *[http://www.aorldbookwritummanward] attacks to poerify distributions in the most emphasists who they reprecuted the chain Probably Aport ''Policia'' (abro; for Austleing powerful time). Chemically were given up eo. ''Adopho Queens'' were defined as Panestes of the cas
# Epoch 5 batch 200/1945, loss 1.4529913663864136, time 0.5927407741546631
#
#  to the graveling of exactly television fight as which [[Armenian Series in View]].
# * '''Heming group of new persons itself''' &amp;#1003;&amp;#1576;&amp;#1905;&amp;#12504;&amp;#1023;&amp;#1495;&amp;#1100;&amp;#1095;&amp;#1554; &amp;#1515;&amp;#1302;&amp;141;&amp;#1648;&amp;#1448;&amp;#1496;&amp;#144
# Epoch 5 batch 300/1945, loss 1.3630911111831665, time 0.5987186431884766
#
#  185&amp;#86188;}}&lt;/small&gt;
# |colspan=&quot;24&quot; | 3.03 &lt;br&gt;''e.g., [[floopedyday]]='')
# |2A
# | ''(1, conservatio of ''[[Interface]]'')
# |-
# | &lt;small&gt;'''{{IPA|b}} (Nazi Z2.''', ''öthau''  - YUMP)(RM)||
# called = 1,704,400 (2005 est.
#
# The [[Stokes|Italian]] bank hosmalis
#  | Year brunes
# Epoch 5 batch 400/1945, loss 1.2719194889068604, time 0.5931522846221924
#
#  group of FiylarE/ 22,200 joyanians parteted escoricality and hilled profiles of the book, set of Daruil (25% of Boston's king)|Jesus/flankage' 33, 0: 358:27: newspaper, 10:16 ali-ring ritumnicorating sources are appeared as [[0 Samuel (mameha)|Japanese 40: 9]] and man moved to for &quot;to attractio
# Epoch 5 batch 500/1945, loss 1.4287199974060059, time 0.600959062576294
#
#  with [[Day Clash I]] and emith on the [[Chesision of Scrubo]],[[Quebec]] ([[Malay]]) returned to the [[Burg (language)|Great Cuba]], [[Vegginualo]], [[Batman]] actor. Lithuanian practicum was separed by [[Confl Tann, London|Japanese]], an exactly first little known as the word, although using [[Gren
# Epoch 5 batch 600/1945, loss 1.207087516784668, time 0.5990104675292969
#
#  Cartologille]] that had trough existing to semeters, comparably known to either railers and were completely:
# ; a zebs &lt;math&gt; +,\over \ isef \in-f\psicc (2^3)}} as [[psychology|ship]] in population for nocals)
#
# He explained applications about the Widburn television comes for greatest revided wi
# Epoch 5 batch 700/1945, loss 1.4102003574371338, time 0.5917987823486328
#
#  on [[GrandwoFL (1980|GBAEEC]]), child in the ansumption, it history.
#
# ==Minotholes to their nature==
# A yard that people is ordained by for tender ends
#
# ==External links==
# [[Image:Cabological methoon Canadian. Growillars, incident-sea]
# * [http://med6654.sea.com.invulf.org/nunople/ND Cyclassipat23/Gal
# Epoch 5 batch 800/1945, loss 1.3648329973220825, time 0.5921018123626709
#
#  Ibol sessions
# An histim Roops. &quot;You Lanker,&quot; in the population, a question for Survey, as during the Catholic and Park.
#
# He was not responsible simply 5.04 bitter. Some actual [[theory]] of the C(cogg) time most powerful to Leader, drug
# *[[Colven Ryumer]] - [[Moz world]]
# *[[John Hulprowiee
# Epoch 5 batch 900/1945, loss 1.3714308738708496, time 0.5954561233520508
#
#  II]], [[Thomas Massakiersk]]
# *[[Chemodo]], Onliee in how the [[Perhaps: The Doctor Institute of Camerouseline]]
# * [http://www.grots.kvo.uo Goney.]
# *DDV-9 people:
# *Head Press F.A., 2002 Eding, Sansar's League help (8, CTV), Bridge WVM, Vice with tools decime, Cambridge Jones Award]
#
# Man]
# * [http://w
# Epoch 5 batch 1000/1945, loss 1.3820096254348755, time 0.6023139953613281
#
#  Déub]]
# *[[ENGUPA did UK]]
#
# ==History==
# Head beeked by [[Johnny Drive]] were only born by Kent developed contributing in the ''[[Metro]]'' in [[Medal of War, 9th Vesisham]], which suo of the [[New Year Taling]] of the CPUCOX region which would low drawl cardinal equipped distance and thunderstown in
# Epoch 5 batch 1100/1945, loss 1.3825737237930298, time 0.5948073863983154
#
#  [[2003]] and a general shelf was buried by such the Echisoff (she has either suggested a [[identity (vicroductions)|fall]] and [[derles]]'s appletenets, &quot;to any height during historian.'SIPASPC In Culty|TRSDI], IAkurij in Usually, Mode on Scolcire Shaglesons, Estus drive the river of owagents t
# Epoch 5 batch 1200/1945, loss 1.3910292387008667, time 0.589388370513916
#
#  after New Zealand, Five the same musical objections, including [[Mondal Perha fellig of Jesus]], [[2003]], other surrendered world profit were tisness.  Method of the latter commendanuls of [[hastingsion]] is also condited.  In the reality, the PROF dependencies are able to the military only resulte
# Epoch 5 batch 1300/1945, loss 1.1597973108291626, time 0.594536304473877
#
#  in generation teachings or points on [[John Roth]] and a [[duchy ego]], the same, benefic initial mergers of a vio can gather into in the same rite. Eniguad that he has first volar for successing to such as a [Constitutional (d. [[1950]]) fusion is established to murdered approaches such as '''CS'''
# Epoch 5 batch 1400/1945, loss 1.3888614177703857, time 0.5947539806365967
#
#  of [[American revolutionist]] [[economic equator]]
#
# Uraging hosted aircraft [[image:nlate_brunveniation_jarpsy.pagesy.br&gt;
# services on the collection of comic worry, and the country of macro autonomy, and certain schools prospects of under length VI. His predecessor, honeyly of the Gulony
# #[[Vero
# Epoch 5 batch 1500/1945, loss 1.3625670671463013, time 0.5921845436096191
#
#  Phino]]
# * Charles to the Thachen Atlantic Culture series
# :[[Helbert Navy]] - Champ sent, , in the disputation, constituted Octo's particioners between his domination could seek ''Georgge's defence: ''Operatione's Soning Tany'', &quot;In writers d'&quot; atomists, Francon, and retaine reading spreadn
# Epoch 5 batch 1600/1945, loss 1.3499850034713745, time 0.5919551849365234
#
#  religion; homine communication business&quot;, Chnowabius Internet Horalle Personry Service Angeles, Neverth relations on a long myth of [[Na variant| people of Civilization ]]. The weapon of Instance of Ash, see the job belongs a few kinn species popular in his most oldest official too, Newers (Naz
# Epoch 5 batch 1700/1945, loss 1.3939253091812134, time 0.5998601913452148
#
#  Renakhbory|UK]] world-celebrated using [[Russianot Tulurus]] ''New Expansience'', became an also per past acceleration to guide for most grew carded as practice that point from a 'response money-infoburated will have-side (betten ''f'' agin]. Linguism, or &quot;anall&quot; Amendasided in everything
# Epoch 5 batch 1800/1945, loss 1.5790654420852661, time 0.5931150913238525
#
#  it can machine its the same it or servor.
#
# '''Italo-low''' are megatrict{{fquanebna hypno|Union round banald]]: in the first impact of over the creation systems, pauses speaking contains isour rightsings, completely freedoms, and they issue be some divided
#
# *Takinghous fans alanding in partical em
# Epoch 5 batch 1900/1945, loss 1.332075595855713, time 0.5948822498321533
# DONE EPOCH 5, AVG LOSS 1.3507033528429684, TIME 826.9562947750092
#
#  video my point press accountly, keyboard museums called Present years. This days of flend.&quot;
#
# ==Formerly later of the Game closus rights ==
# The atomic amounts may also vivons were seized before institutional geather Rome. Credibly 25 meets as the pattern and semicond detosing modern phenopy Cent
# Epoch 6 batch 0/1945, loss 1.323935627937317, time 0.5985105037689209
#
#  Dekononautic Church, ''Marshust'' Intelfes' mutually (of ADS) did not about 600 koo-meet of an infection translated and ''microscopic value''.  Bavacha general cartridge actor proponents.  The French friend saats that the following only 28°N from the moment into 1800s the Great Family (music on the
# Epoch 6 batch 100/1945, loss 1.3571712970733643, time 0.5919795036315918
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-e276e9eaf638> in <module>()
#      10             for idx, X_batch in enumerate(batched):
#      11                 start = time.time()
# ---> 12                 loss = char_lm.learn_batch(X_batch, sess)
#      13                 epoch_loss += loss
#      14                 if idx % 100 == 0:
#
# <ipython-input-11-56f3bc8d81c1> in learn_batch(self, X_batch, sess)
#      63
#      64     def learn_batch(self, X_batch, sess):
# ---> 65         loss, _ = sess.run([self.loss, self.optimizer], feed_dict={self.inputs: X_batch})
#      66         return loss
#      67
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     715     try:
#     716       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 717                          run_metadata_ptr)
#     718       if run_metadata:
#     719         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     913     if final_fetches or final_targets:
#     914       results = self._do_run(handle, final_targets, final_fetches,
# --> 915                              feed_dict_string, options, run_metadata)
#     916     else:
#     917       results = []
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#     963     if handle is None:
#     964       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# --> 965                            target_list, options, run_metadata)
#     966     else:
#     967       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#     970   def _do_call(self, fn, *args):
#     971     try:
# --> 972       return fn(*args)
#     973     except errors.OpError as e:
#     974       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#     952         return tf_session.TF_Run(session, options,
#     953                                  feed_dict, fetch_list, target_list,
# --> 954                                  status, run_metadata)
#     955
#     956     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# Такую же быструю реализацию, как GRUCell написать не удалось, но мы подобрались вплотную (0.6 s/batch vs 0.5 s/batch). Еще наша реализация сходится чуть-чуть быстрее, но возможно это в пределах погрешности. Примечательно, что не смотря на то, что время, уходящее на один батч в нашей реализации чуть больше, суммарное время, потраченное на эпоху, оказалось немного меньше. Возможно, в нашей моделе бытсрее происходит inference для сэмплинга

# %% [markdown]
# ```
# CUSTOM GRU CELL
# DONE EPOCH 0, AVG LOSS 2.1978992079094932, TIME 827.3081226348877
# DONE EPOCH 1, AVG LOSS 1.5335701902911718, TIME 826.921665430069
# DONE EPOCH 2, AVG LOSS 1.4430663428760127, TIME 827.1765003204346
# DONE EPOCH 3, AVG LOSS 1.3984494707578252, TIME 827.0133855342865
# DONE EPOCH 4, AVG LOSS 1.370269677326428, TIME 827.1113862991333
# DONE EPOCH 5, AVG LOSS 1.3507033528429684, TIME 826.9562947750092```

# %% [markdown]
# ```
# TF GRU CELL
# DONE EPOCH 0, AVG LOSS 2.271053379176515, TIME 839.5970721244812
# DONE EPOCH 1, AVG LOSS 1.5493454257136445, TIME 838.909827709198
# DONE EPOCH 2, AVG LOSS 1.4537357697450104, TIME 838.884211063385```
